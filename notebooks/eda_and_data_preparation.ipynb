# %% [markdown]
# # Attrition Model - Exploratory Data Analysis

# %% [markdown]
# ## Project Description:
#
# Definitions:
# - `Attrition` is the departure of employees from the organization for any reason (voluntary or involuntary), including resignation, termination, death or retirement.
#
#
# Assumptions:
# - Ordinal metrics from 1-N showcase that 1 is a low value and N is a high value
#     - JobLevel of 5 is like an executive. Range: [1,2,3,4, 5]
#     - PerformanceRating of 4 is Great performance.  Range: [1,2,3,4]
#     - JobSatisfaction of 4 is Great performance. Range: [1,2,3,4]
# - EmployeeID is unique field

# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost
import mlflow
import warnings

from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
mpl.rcParams['font.family'] = 'sans-serif'

# Show all columns
pd.set_option('display.max_columns', None)

# %%
random_state_var = 42
random_state_var
# Out:
# 42

# %%
np.random.seed(random_state_var)

# %%
# Add my parent directory to path variables
current_location = Path(os.path.abspath('')).parent.resolve()
print(current_location)
sys.path.append(str(current_location))
# Out:
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code

# %%
data_dir = os.path.join(current_location, "data")

raw_data_dir = os.path.join(data_dir, "raw_data")
os.makedirs(raw_data_dir, exist_ok=True)

transformed_data_dir = os.path.join(data_dir, "transformed_data")
os.makedirs(transformed_data_dir, exist_ok=True)

output_data_dir = os.path.join(data_dir, "output_data")
os.makedirs(output_data_dir, exist_ok=True)

# %% [markdown]
# ## Connect to MLFlow:
#
#
# ### Ensure you run this once:

# %%
# !mlflow.set_tracking_uri("file:///Users/ryanmccarlie/Documents/Problems/PwC%20Interview/Code/mlruns")
# Out:
# zsh:1: invalid mode specification

# %%
def get_or_create_experiment(experiment_name: str) -> str:
    """
    Fetches the experiment with the given name if it exists. If it doesn't exist, creates a new one.
    
    Parameters:
    - experiment_name (str): The name of the MLFlow experiment.
    
    Returns:
    - experiment_id (str): The ID of the experiment to use.
    """
    mlflow.set_tracking_uri("file:///Users/ryanmccarlie/Documents/Problems/PwC%20Interview/Code/mlruns")

    # Fetch the experiment if it exists
    try:
        experiment = mlflow.get_experiment_by_name(experiment_name)
        if experiment is not None:
            print(f"Experiment '{experiment_name}' exists with ID: {experiment.experiment_id}")
            return experiment.experiment_id
        else:
            # Create a new experiment if it does not exist
            experiment_id = mlflow.create_experiment(experiment_name)
            print(f"Created new experiment '{experiment_name}' with ID: {experiment_id}")
            return experiment_id
    except mlflow.MlflowException as e:
        print(f"Error: {e}")
        raise

# %%
# Example usage
experiment_name = "Employee_Attrition_ExperimentScript"

# Get or create the experiment
experiment_id = get_or_create_experiment(experiment_name)

# Set the experiment ID for subsequent logging
mlflow.set_experiment(experiment_id=experiment_id)
# Out:
# Experiment 'Employee_Attrition_ExperimentScript' exists with ID: 919752868874657414
# <Experiment: artifact_location='file:///Users/ryanmccarlie/Documents/Problems/PwC%20Interview/Code/mlruns/919752868874657414', creation_time=1726905754912, experiment_id='919752868874657414', last_update_time=1726905754912, lifecycle_stage='active', name='Employee_Attrition_ExperimentScript', tags={'mlflow.sharedViewState.f9cbb98e7827c2a2615434cfc5dbc9f9c23b9a6268feed2a3bef82206d68bb20': 'deflate;...'}>

# %% [markdown]
# ## 1. Read in Data

# %%
attrition_fname = os.path.join(raw_data_dir, "employee_attrition_data_final.xlsx")
employee_attribution_data = pd.read_excel(attrition_fname)

print(employee_attribution_data.columns)
print(employee_attribution_data.shape)
employee_attribution_data.head()
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'Department', 'Education',
#        'MaritalStatus', 'YearsAtCompany', 'JobRole', 'MonthlyIncome',
#        'OverTime', 'BusinessTravel', 'DistanceFromHome', 'JobLevel',
#        'PercentSalaryHike', 'PerformanceRating', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'JobSatisfaction',
#        'Attrition'],
#       dtype='object')
# (5000, 20)
#    EmployeeID   Age  Gender Department    Education MaritalStatus  \
# 0           1  56.0    Male    Support      Masters       Married
# 1           2  46.0  Female      Sales    Bachelors        Single
# 2           3  32.0    Male         HR          PhD        Single
# 3           4  60.0    Male    Support          PhD        Single
# 4           5  25.0    Male    Support  High School        Single
#
#    YearsAtCompany     JobRole  MonthlyIncome OverTime     BusinessTravel  \
# 0             9.0  Technician          19844       No  Travel_Frequently
# 1            29.0    Engineer           6687       No         Non-Travel
# 2            35.0       Clerk           7357       No         Non-Travel
# 3            39.0  Technician           2327      Yes      Travel_Rarely
# 4            14.0   Executive          12285      Yes      Travel_Rarely
#
#    DistanceFromHome JobLevel  PercentSalaryHike PerformanceRating  \
# 0                 9        4                 24                 2
# 1                39        1                 20                 1
# 2                 1        1                 12                 1
# 3                33        1                  0                 2
# 4                38        5                 24                 3
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                 2.0                      1.0                     0
# 1                14.0                     11.0                     7
# 2                11.0                      7.0                     0
# 3                12.0                      6.0                     5
# 4                 9.0                      4.0                     9
#
#   JobSatisfaction Attrition
# 0               1        No
# 1               1        No
# 2               4       Yes
# 3          "3.00"       Yes
# 4               3       Yes

# %%
assert employee_attribution_data["EmployeeID"].is_unique

# %%
if employee_attribution_data["EmployeeID"].is_unique:
    employee_attribution_data = employee_attribution_data.drop(columns=["EmployeeID"])
    
employee_attribution_data.head(2)
# Out:
#     Age  Gender Department  Education MaritalStatus  YearsAtCompany  \
# 0  56.0    Male    Support    Masters       Married             9.0
# 1  46.0  Female      Sales  Bachelors        Single            29.0
#
#       JobRole  MonthlyIncome OverTime     BusinessTravel  DistanceFromHome  \
# 0  Technician          19844       No  Travel_Frequently                 9
# 1    Engineer           6687       No         Non-Travel                39
#
#   JobLevel  PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 0        4                 24                 2                 2.0
# 1        1                 20                 1                14.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction Attrition
# 0                      1.0                     0               1        No
# 1                     11.0                     7               1        No

# %%
list(employee_attribution_data.columns)
# Out:
# ['Age',
#  'Gender',
#  'Department',
#  'Education',
#  'MaritalStatus',
#  'YearsAtCompany',
#  'JobRole',
#  'MonthlyIncome',
#  'OverTime',
#  'BusinessTravel',
#  'DistanceFromHome',
#  'JobLevel',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'JobSatisfaction',
#  'Attrition']

# %%
employee_attribution_data.dtypes.to_dict()
# Out:
# {'Age': dtype('float64'),
#  'Gender': dtype('O'),
#  'Department': dtype('O'),
#  'Education': dtype('O'),
#  'MaritalStatus': dtype('O'),
#  'YearsAtCompany': dtype('float64'),
#  'JobRole': dtype('O'),
#  'MonthlyIncome': dtype('int64'),
#  'OverTime': dtype('O'),
#  'BusinessTravel': dtype('O'),
#  'DistanceFromHome': dtype('int64'),
#  'JobLevel': dtype('O'),
#  'PercentSalaryHike': dtype('int64'),
#  'PerformanceRating': dtype('O'),
#  'YearsInCurrentRole': dtype('float64'),
#  'YearsSinceLastPromotion': dtype('float64'),
#  'YearsWithCurrManager': dtype('int64'),
#  'JobSatisfaction': dtype('O'),
#  'Attrition': dtype('O')}

# %%
target_class = "Attrition"
employee_attribution_data[target_class].value_counts()
# Out:
# Attrition
# No     3149
# Yes    1851
# Name: count, dtype: int64

# %%
employee_attribution_data.describe()
# Out:
#                Age  YearsAtCompany  MonthlyIncome  DistanceFromHome  \
# count  4997.000000     4992.000000   5.000000e+03       5000.000000
# mean     41.243346       35.735777   1.157740e+04         24.990600
# std      13.676054      399.376981   2.607094e+04         14.089436
# min       4.000000        0.000000   2.000000e+03          1.000000
# 25%      30.000000       10.000000   6.642000e+03         13.000000
# 50%      41.000000       20.000000   1.115200e+04         25.000000
# 75%      53.000000       30.000000   1.557850e+04         37.000000
# max      99.000000     9999.000000   1.532624e+06         49.000000
#
#        PercentSalaryHike  YearsInCurrentRole  YearsSinceLastPromotion  \
# count        5000.000000         4998.000000              4997.000000
# mean           21.964600           20.757303                12.303582
# std           315.774936          286.886692               202.894029
# min             0.000000            0.000000                 0.000000
# 25%             6.000000            2.250000                 1.000000
# 50%            12.000000            7.000000                 3.000000
# 75%            18.000000           15.000000                 7.000000
# max          9999.000000         9590.000000              7359.000000
#
#        YearsWithCurrManager
# count           5000.000000
# mean              11.911800
# std              198.255181
# min                0.000000
# 25%                1.000000
# 50%                3.000000
# 75%                7.000000
# max             7444.000000

# %% [markdown]
# ## Notes:
# - looks like w have some anomalies in the max values column for sure

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### 2.0 Drop NaN Columns

# %%
employee_attribution_data.isnull().mean()
# Out:
# Age                        0.0006
# Gender                     0.0000
# Department                 0.0000
# Education                  0.0000
# MaritalStatus              0.0000
# YearsAtCompany             0.0016
# JobRole                    0.0000
# MonthlyIncome              0.0000
# OverTime                   0.0000
# BusinessTravel             0.0000
# DistanceFromHome           0.0000
# JobLevel                   0.0000
# PercentSalaryHike          0.0000
# PerformanceRating          0.0004
# YearsInCurrentRole         0.0004
# YearsSinceLastPromotion    0.0006
# YearsWithCurrManager       0.0000
# JobSatisfaction            0.0000
# Attrition                  0.0000
# dtype: float64

# %%
from utils.cleaning import drop_columns_with_missing_data


employee_attribution_data, columns_to_drop= drop_columns_with_missing_data(
    df=employee_attribution_data,
    nan_data_threshold_perc=0.5
)
print(f"Dropping columns: {columns_to_drop}")
print(employee_attribution_data.shape)
# Out:
# Dropping columns: []
# (5000, 19)

# %% [markdown]
# ### 2.1 Correct String Values in Numeric Columns

# %%
corrected_df = employee_attribution_data.copy()

corrected_df.shape
# Out:
# (5000, 19)

# %%
from utils.cleaning import identify_numeric_columns_with_object_type, correct_numeric_columns_with_object_type

columns_w_string_values = identify_numeric_columns_with_object_type(corrected_df)
print(f"columns_w_string_values: {columns_w_string_values}")
# Out:
# columns_w_string_values: ['JobLevel', 'PerformanceRating', 'JobSatisfaction']

# %%
corrected_df[~corrected_df["JobSatisfaction"].isin([1,2,3,4,5])]["JobSatisfaction"].values
# Out:
# array(['"3.00"', '"3.00"', '"2.00"', '"2.00"', '"3.00"', '"2.00"',
#        '"2.00"', '"3.00"', '"2.00"', '"2.00"'], dtype=object)

# %%
corrected_df["JobSatisfaction"].dtypes
# Out:
# dtype('O')

# %%
for col_name in columns_w_string_values:    
    corrected_df.loc[:, col_name] = corrected_df[col_name].apply(correct_numeric_columns_with_object_type)
    corrected_df[col_name] = pd.to_numeric(corrected_df[col_name])

# %%
print(corrected_df.shape)

print(corrected_df["JobSatisfaction"].dtypes)
corrected_df[~corrected_df["JobSatisfaction"].isin([1,2,3,4,5])]["JobSatisfaction"].values
# Out:
# (5000, 19)
# float64
# array([], dtype=float64)

# %%
corrected_df.dtypes
# Out:
# Age                        float64
# Gender                      object
# Department                  object
# Education                   object
# MaritalStatus               object
# YearsAtCompany             float64
# JobRole                     object
# MonthlyIncome                int64
# OverTime                    object
# BusinessTravel              object
# DistanceFromHome             int64
# JobLevel                   float64
# PercentSalaryHike            int64
# PerformanceRating          float64
# YearsInCurrentRole         float64
# YearsSinceLastPromotion    float64
# YearsWithCurrManager         int64
# JobSatisfaction            float64
# Attrition                   object
# dtype: object

# %% [markdown]
# ### 2.2 Impute or Remove NaN Values

# %%
corrected_df.shape
# Out:
# (5000, 19)

# %%
nan_columns = corrected_df.columns[corrected_df.isna().any()].tolist()
print("nan_columns", nan_columns)

corrected_df.isnull().sum()  # Check for missing values
# Out:
# nan_columns ['Age', 'YearsAtCompany', 'PerformanceRating', 'YearsInCurrentRole', 'YearsSinceLastPromotion']
# Age                        3
# Gender                     0
# Department                 0
# Education                  0
# MaritalStatus              0
# YearsAtCompany             8
# JobRole                    0
# MonthlyIncome              0
# OverTime                   0
# BusinessTravel             0
# DistanceFromHome           0
# JobLevel                   0
# PercentSalaryHike          0
# PerformanceRating          2
# YearsInCurrentRole         2
# YearsSinceLastPromotion    3
# YearsWithCurrManager       0
# JobSatisfaction            0
# Attrition                  0
# dtype: int64

# %%
print(corrected_df[corrected_df.isna().any(axis=1)].shape)
corrected_df[corrected_df.isna().any(axis=1)]
# Out:
# (18, 19)
#        Age  Gender   Department    Education MaritalStatus  YearsAtCompany  \
# 8     40.0  Female           HR  High School        Single             NaN
# 358   57.0  Female        Sales  High School      Divorced             NaN
# 1058  50.0    Male        Sales    Bachelors      Divorced             NaN
# 1863  19.0    Male      Support    Bachelors      Divorced             NaN
# 1914   NaN    Male  Development      Masters       Married            26.0
# 1999  23.0  Female      Finance    Bachelors      Divorced             8.0
# 2493  42.0    Male  Development    Bachelors       Married             NaN
# 2734  45.0  Female  Development    Bachelors      Divorced            23.0
# 2909  18.0  Female        Sales    Bachelors       Married             2.0
# 3124  51.0  Female      Support          PhD      Divorced             NaN
# 3189  42.0  Female      Support      Masters        Single             1.0
# 3520   NaN    Male      Finance          PhD      Divorced            19.0
# 3646   NaN  Female      Finance  High School      Divorced            39.0
# 3679  59.0    Male           HR    Bachelors       Married            24.0
# 4000  51.0  Female        Sales      Masters       Married             NaN
# 4203  62.0    Male      Finance          PhD       Married            12.0
# 4735  25.0    Male        Sales    Bachelors       Married             NaN
# 4974  32.0  Female           HR      Masters      Divorced            25.0
#
#          JobRole  MonthlyIncome OverTime     BusinessTravel  DistanceFromHome  \
# 8       Engineer          17540       No      Travel_Rarely                32
# 358        Clerk          19916       No  Travel_Frequently                48
# 1058     Manager           7789      Yes  Travel_Frequently                12
# 1863     Manager          14571      Yes      Travel_Rarely                22
# 1914    Engineer          17473      Yes  Travel_Frequently                47
# 1999       Clerk          16262      Yes      Travel_Rarely                21
# 2493     Manager           8673      Yes         Non-Travel                35
# 2734  Technician          18966      Yes         Non-Travel                18
# 2909     Manager          11291       No  Travel_Frequently                41
# 3124       Clerk          13180       No  Travel_Frequently                15
# 3189       Clerk          11734      Yes         Non-Travel                27
# 3520    Engineer          15672       No      Travel_Rarely                13
# 3646    Engineer          13086       No      Travel_Rarely                15
# 3679       Clerk           7988       No         Non-Travel                35
# 4000  Technician           5323      Yes         Non-Travel                48
# 4203       Clerk           7402       No  Travel_Frequently                36
# 4735  Technician          13164       No      Travel_Rarely                32
# 4974       Clerk          18913      Yes      Travel_Rarely                21
#
#       JobLevel  PercentSalaryHike  PerformanceRating  YearsInCurrentRole  \
# 8          2.0                 12                4.0                 0.0
# 358        3.0                 21                4.0                 0.0
# 1058       2.0                  9                4.0                 0.0
# 1863       1.0                 15                3.0                 0.0
# 1914       4.0                  0                1.0                10.0
# 1999       1.0                 19                4.0                 NaN
# 2493       5.0                  9                2.0                 0.0
# 2734       3.0                  1                4.0                 NaN
# 2909       3.0                  1                NaN                 2.0
# 3124       5.0                 14                1.0                 0.0
# 3189       1.0                  5                2.0                 1.0
# 3520       4.0                 21                2.0                 9.0
# 3646       5.0                 23                4.0                 8.0
# 3679       1.0                  7                NaN                14.0
# 4000       5.0                 17                1.0                 0.0
# 4203       2.0                 21                2.0                 3.0
# 4735       3.0                  4                1.0                 0.0
# 4974       5.0                 12                4.0                 3.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager  JobSatisfaction Attrition
# 8                         0.0                     0              2.0       Yes
# 358                       0.0                     0              3.0        No
# 1058                      0.0                     0              4.0       Yes
# 1863                      0.0                     0              1.0        No
# 1914                      8.0                     5              1.0        No
# 1999                      3.0                     0              2.0       Yes
# 2493                      0.0                     0              2.0       Yes
# 2734                      7.0                    11              3.0        No
# 2909                      2.0                     1              2.0        No
# 3124                      0.0                     0              4.0       Yes
# 3189                      NaN                     1              3.0        No
# 3520                      7.0                     0              4.0        No
# 3646                      7.0                     4              3.0        No
# 3679                      9.0                     3              3.0       Yes
# 4000                      0.0                     0              2.0       Yes
# 4203                      NaN                     1              2.0        No
# 4735                      0.0                     0              1.0        No
# 4974                      NaN                     3              2.0       Yes

# %%
# Fill missing values
from utils.cleaning import fill_missing_values

df_no_nan = fill_missing_values(corrected_df)
df_no_nan.isnull().sum()
# Out:
# Age                        0
# YearsAtCompany             0
# MonthlyIncome              0
# DistanceFromHome           0
# JobLevel                   0
# PercentSalaryHike          0
# PerformanceRating          0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# JobSatisfaction            0
# Gender                     0
# Department                 0
# Education                  0
# MaritalStatus              0
# JobRole                    0
# OverTime                   0
# BusinessTravel             0
# Attrition                  0
# dtype: int64

# %%
print(df_no_nan.shape)
df_no_nan[df_no_nan.isna().any(axis=1)]
# Out:
# (5000, 19)
# Empty DataFrame
# Columns: [Age, YearsAtCompany, MonthlyIncome, DistanceFromHome, JobLevel, PercentSalaryHike, PerformanceRating, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, JobSatisfaction, Gender, Department, Education, MaritalStatus, JobRole, OverTime, BusinessTravel, Attrition]
# Index: []

# %% [markdown]
# ### 2.3 YearsAtCompany Feature Cleaning
#
#
# Remove all employees which have 0 years worked
#
# Why?
# - Either (1) these values are a bug or (2) the employee has worked less that 6 months.
#     - In the first case, remove data.
#     - In the second case, then these data points are not adding value to the model to identify for historic trends or relationships. New employees will have highly variable features which will not be a true representation of their ability or true meaning.

# %%
df_no_nan[df_no_nan['YearsAtCompany'] > 0].shape
# Out:
# (4893, 19)

# %%
print(f"Dropped {df_no_nan[df_no_nan['YearsAtCompany'] <= 0].shape[0]} rows")
df_no_nan = df_no_nan[df_no_nan['YearsAtCompany'] > 0]

print(df_no_nan.shape)
df_no_nan.head(2)
# Out:
# Dropped 107 rows
# (4893, 19)
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome  JobLevel  \
# 0  56.0             9.0        19844.0               9.0       4.0
# 1  46.0            29.0         6687.0              39.0       1.0
#
#    PercentSalaryHike  PerformanceRating  YearsInCurrentRole  \
# 0               24.0                2.0                 2.0
# 1               20.0                1.0                14.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager  JobSatisfaction  Gender  \
# 0                      1.0                   0.0              1.0    Male
# 1                     11.0                   7.0              1.0  Female
#
#   Department  Education MaritalStatus     JobRole OverTime     BusinessTravel  \
# 0    Support    Masters       Married  Technician       No  Travel_Frequently
# 1      Sales  Bachelors        Single    Engineer       No         Non-Travel
#
#   Attrition
# 0        No
# 1        No

# %%
df_no_nan.dtypes
# Out:
# Age                        float64
# YearsAtCompany             float64
# MonthlyIncome              float64
# DistanceFromHome           float64
# JobLevel                   float64
# PercentSalaryHike          float64
# PerformanceRating          float64
# YearsInCurrentRole         float64
# YearsSinceLastPromotion    float64
# YearsWithCurrManager       float64
# JobSatisfaction            float64
# Gender                      object
# Department                  object
# Education                   object
# MaritalStatus               object
# JobRole                     object
# OverTime                    object
# BusinessTravel              object
# Attrition                   object
# dtype: object

# %% [markdown]
# ## Remove rows with an Age less than 18

# %%
df_no_nan = df_no_nan[df_no_nan["Age"] < 18]


df_no_nan.shape
# Out:
#       Age  YearsAtCompany  MonthlyIncome  DistanceFromHome  JobLevel  \
# 722   7.0            38.0        18132.0              28.0       2.0
# 1578  4.0            33.0        13526.0               1.0       5.0
#
#       PercentSalaryHike  PerformanceRating  YearsInCurrentRole  \
# 722                22.0                2.0                13.0
# 1578               18.0                1.0                32.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager  JobSatisfaction  Gender  \
# 722                       9.0                   5.0              1.0    Male
# 1578                     29.0                   1.0              1.0  Female
#
#      Department Education MaritalStatus     JobRole OverTime BusinessTravel  \
# 722       Sales       PhD      Divorced  Technician      Yes  Travel_Rarely
# 1578    Support   Masters        Single       Clerk      Yes     Non-Travel
#
#      Attrition
# 722        Yes
# 1578        No

# %%
save_to_dash = True

if save_to_dash:
    dash_data = df_no_nan.copy()
    target_class_str_mapper = {
        "No": 0,
        "Yes": 1,
    }
    target_class_str = "Attrition"
    target_class = "target"
    dash_data[target_class] = dash_data[target_class_str].apply(lambda x: target_class_str_mapper[x])
    dash_data = dash_data.drop(columns=["Attrition"])

    dashboard_data_fname = os.path.join(transformed_data_dir, "dashboard_display_data.csv")
    dash_data.to_csv(dashboard_data_fname, index=False)

# %%
 
def plot_categorical_columns(df: pd.DataFrame, columns_per_row: int = 4, width=16, height_per_row = 3):
    """
    Plots bar charts for all categorical columns in the dataframe, with a specific number of plots per row.
    
    Parameters:
    - df (pd.DataFrame): The input dataframe.
    - columns_per_row (int): The number of plots to show in each row.
    """
    # Get all object (categorical) columns
    object_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()
    
    if object_columns == 0:
        return
    
    # Calculate the number of rows required for the plot layout
    num_columns = len(object_columns)
    num_rows = (num_columns + columns_per_row - 1) // columns_per_row  # To handle uneven number of columns

    # Create subplots
    fig, axes = plt.subplots(num_rows, columns_per_row, figsize=(width, num_rows * height_per_row))

    # Flatten axes in case of a single row
    axes = axes.flatten()

    # Loop through each categorical column and plot the value counts
    for i, col in enumerate(object_columns):
        # Get value counts for the column
        value_counts = df[col].value_counts()

        # Plot on the corresponding subplot axis
        axes[i].bar(value_counts.index, value_counts.values, color='skyblue')
        axes[i].set_title(col)
        axes[i].tick_params(axis='x', rotation=45, labelsize=8)  # Rotate x-axis labels and set size
        axes[i].set_ylabel('Count')
        axes[i].set_xlabel(col)

    # Remove unused subplots if there are any
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.suptitle("Categorical Features\n", fontsize=20)
    plt.tight_layout()
# Out:
# [autoreload of utils.visualisation failed: Traceback (most recent call last):
#   File "/Users/ryanmccarlie/.pyenv/versions/3.11.6/envs/PwC-Attrition-model-3.11/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/ryanmccarlie/.pyenv/versions/3.11.6/envs/PwC-Attrition-model-3.11/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/ryanmccarlie/.pyenv/versions/3.11.6/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py", line 189, in <module>
#     model: Pipeline,
#           ^^^^^^^^
# NameError: name 'Pipeline' is not defined
# ]

# %%
# from utils.visualisation import plot_categorical_columns

# Plot bar charts for categorical columns
plot_categorical_columns(df_no_nan, width=16, height_per_row=6)

# %% [markdown]
# ### 2.4 Apply Outlier Detection

# %%
df_pre_outliers_removed = df_no_nan.copy()
df_pre_outliers_removed.shape
# Out:
# (4893, 19)

# %%
# 'Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'JobLevel', 'PercentSalaryHike', 'PerformanceRating',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'JobSatisfaction', 'Gender', 'Department', 'Education', 'MaritalStatus',
#        'JobRole', 'OverTime', 'BusinessTravel', 'Attrition',

# %%
df_pre_outliers_removed['JobLevel'] = df_pre_outliers_removed['JobLevel'].astype('category')
df_pre_outliers_removed['PerformanceRating'] = df_pre_outliers_removed['PerformanceRating'].astype('category')
df_pre_outliers_removed['JobSatisfaction'] = df_pre_outliers_removed['JobSatisfaction'].astype('category')

df_pre_outliers_removed.dtypes
# Out:
# Age                         float64
# YearsAtCompany              float64
# MonthlyIncome               float64
# DistanceFromHome            float64
# JobLevel                   category
# PercentSalaryHike           float64
# PerformanceRating          category
# YearsInCurrentRole          float64
# YearsSinceLastPromotion     float64
# YearsWithCurrManager        float64
# JobSatisfaction            category
# Gender                       object
# Department                   object
# Education                    object
# MaritalStatus                object
# JobRole                      object
# OverTime                     object
# BusinessTravel               object
# Attrition                    object
# dtype: object

# %%
categorical_columns = df_pre_outliers_removed.select_dtypes(include=['object', 'category']).columns
print("categorical_columns", categorical_columns)
print()

numeric_columns = df_pre_outliers_removed.select_dtypes(include=['float64', 'int64']).columns
print("numeric_columns", numeric_columns)

assert df_pre_outliers_removed.shape[1] == (len(numeric_columns) + len(categorical_columns))
# Out:
# categorical_columns Index(['JobLevel', 'PerformanceRating', 'JobSatisfaction', 'Gender',
#        'Department', 'Education', 'MaritalStatus', 'JobRole', 'OverTime',
#        'BusinessTravel', 'Attrition'],
#       dtype='object')
#
# numeric_columns Index(['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'PercentSalaryHike', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
def plot_anomaly_detection_results(df: pd.DataFrame, column: str, threshold: float = 3.5, figsize=(16, 6)):
    """
    Plot the results of Modified Z-score anomaly detection.

    :param df: DataFrame containing the data with anomaly detection results.
    :param column: The column on which anomaly detection was performed.
    :param threshold: The threshold used for anomaly detection.
    """
    # Get the median and MAD for the column to calculate bounds
    median = df[column].median()
    mad = np.median(np.abs(df[column] - median))
    upper_bound = median + threshold * mad / 0.6745
    lower_bound = median - threshold * mad / 0.6745
    
    # Plot the histogram with the upper and lower bounds
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # Full data plot (Left plot)
    sns.histplot(df[column], kde=True, ax=axes[0])
    axes[0].axvline(upper_bound, color='r', linestyle='--', label=f'Upper bound ({upper_bound:.2f})')
    axes[0].axvline(lower_bound, color='b', linestyle='--', label=f'Lower bound ({lower_bound:.2f})')
    
    # Count anomalies and display it on the plot
    anomaly_count = df[f'anomaly_{column}'].sum()
    data_mean = df[column].mean()
    std = df[column].std()
    title_t = f"""
        Modified Z-Score Detection: {column}.
        Anomaly Count: {anomaly_count}
        Mean: {data_mean:.2f}
        STD : {std: .2f}
    """
    axes[0].set_title(title_t, fontsize=14)
    axes[0].set_xlabel(column)
    axes[0].set_ylabel('Frequency')
    axes[0].legend()

    # Plot only the data within bounds (Right plot)
    filtered_data = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    filtered_data_mean = filtered_data[column].mean()
    filtered_std = filtered_data[column].std()
    sns.histplot(filtered_data[column], kde=True, ax=axes[1])
    title = f"""
        {column} Data within Bounds
        Filtered Mean: {filtered_data_mean:.2f}
        Filtered STD : {filtered_std: .2f}
    """
    axes[1].set_title(title, fontsize=14)
    axes[1].set_xlabel(column)
    axes[1].set_ylabel('Frequency')

    # Adjust layout and show the plots
    plt.tight_layout()    
    return fig, axes

# %%
# Perform Modified Z-score anomaly detection
from utils.cleaning import modified_z_score_anomaly_detection

plot_zscore_anomalies = True
threshold = 3.0

for column in numeric_columns:
    # Calculate MAD stats
    df = modified_z_score_anomaly_detection(df_pre_outliers_removed, column, threshold)

    # Plot if requested
    if plot_zscore_anomalies:
        print(f"Column: {column}")        
        plot_anomaly_detection_results(df_pre_outliers_removed, column, threshold, figsize=(16, 8))
        plt.show()
# Out:
# Column: Age
# Column: YearsAtCompany
# Column: MonthlyIncome
# Column: DistanceFromHome
# Column: PercentSalaryHike
# Column: YearsInCurrentRole
# Column: YearsSinceLastPromotion
# Column: YearsWithCurrManager

# %%
df_pre_outliers_removed.columns
# Out:
# Index(['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'JobLevel', 'PercentSalaryHike', 'PerformanceRating',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'JobSatisfaction', 'Gender', 'Department', 'Education', 'MaritalStatus',
#        'JobRole', 'OverTime', 'BusinessTravel', 'Attrition',
#        'modified_z_score_Age', 'anomaly_Age',
#        'modified_z_score_YearsAtCompany', 'anomaly_YearsAtCompany',
#        'modified_z_score_MonthlyIncome', 'anomaly_MonthlyIncome',
#        'modified_z_score_DistanceFromHome', 'anomaly_DistanceFromHome',
#        'modified_z_score_PercentSalaryHike', 'anomaly_PercentSalaryHike',
#        'modified_z_score_YearsInCurrentRole', 'anomaly_YearsInCurrentRole',
#        'modified_z_score_YearsSinceLastPromotion',
#        'anomaly_YearsSinceLastPromotion',
#        'modified_z_score_YearsWithCurrManager',
#        'anomaly_YearsWithCurrManager'],
#       dtype='object')

# %%
anomaly_columns = [col for col in df_pre_outliers_removed.columns if col.startswith("anomaly")]
anomaly_columns
# Out:
# ['anomaly_Age',
#  'anomaly_YearsAtCompany',
#  'anomaly_MonthlyIncome',
#  'anomaly_DistanceFromHome',
#  'anomaly_PercentSalaryHike',
#  'anomaly_YearsInCurrentRole',
#  'anomaly_YearsSinceLastPromotion',
#  'anomaly_YearsWithCurrManager']

# %%
# def filter_anomalies(df, anomaly_columns):
#     """
#     Filters a DataFrame to return only the rows where any value in the specified anomaly columns is True.
    
#     :param df: The DataFrame containing the data.
#     :param anomaly_columns: A list of column names that indicate anomalies (boolean columns).
#     :return: Filtered DataFrame where any value in the specified anomaly columns is True.
#     """
#     # Use the any() function to filter rows where any of the anomaly columns are True
#     filtered_df = df[~df[anomaly_columns].any(axis=1)]
    
#     return filtered_df

# %%
df_no_anomalies = df_pre_outliers_removed[~df_pre_outliers_removed[anomaly_columns].any(axis=1)]

print(df_no_anomalies.shape)
df_no_anomalies.head()
# Out:
# (4331, 35)
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 0  56.0             9.0        19844.0               9.0      4.0
# 1  46.0            29.0         6687.0              39.0      1.0
# 2  32.0            35.0         7357.0               1.0      1.0
# 3  60.0            39.0         2327.0              33.0      1.0
# 4  25.0            14.0        12285.0              38.0      5.0
#
#    PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 0               24.0               2.0                 2.0
# 1               20.0               1.0                14.0
# 2               12.0               1.0                11.0
# 3                0.0               2.0                12.0
# 4               24.0               3.0                 9.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 0                      1.0                   0.0             1.0    Male
# 1                     11.0                   7.0             1.0  Female
# 2                      7.0                   0.0             4.0    Male
# 3                      6.0                   5.0             3.0    Male
# 4                      4.0                   9.0             3.0    Male
#
#   Department    Education MaritalStatus     JobRole OverTime  \
# 0    Support      Masters       Married  Technician       No
# 1      Sales    Bachelors        Single    Engineer       No
# 2         HR          PhD        Single       Clerk       No
# 3    Support          PhD        Single  Technician      Yes
# 4    Support  High School        Single   Executive      Yes
#
#       BusinessTravel Attrition  modified_z_score_Age  anomaly_Age  \
# 0  Travel_Frequently        No              0.843125        False
# 1         Non-Travel        No              0.281042        False
# 2         Non-Travel       Yes             -0.505875        False
# 3      Travel_Rarely       Yes              1.067958        False
# 4      Travel_Rarely       Yes             -0.899333        False
#
#    modified_z_score_YearsAtCompany  anomaly_YearsAtCompany  \
# 0                         -0.74195                   False
# 1                          0.60705                   False
# 2                          1.01175                   False
# 3                          1.28155                   False
# 4                         -0.40470                   False
#
#    modified_z_score_MonthlyIncome  anomaly_MonthlyIncome  \
# 0                        1.302068                  False
# 1                       -0.677057                  False
# 2                       -0.576273                  False
# 3                       -1.332905                  False
# 4                        0.165015                  False
#
#    modified_z_score_DistanceFromHome  anomaly_DistanceFromHome  \
# 0                          -0.899333                     False
# 1                           0.786917                     False
# 2                          -1.349000                     False
# 3                           0.449667                     False
# 4                           0.730708                     False
#
#    modified_z_score_PercentSalaryHike  anomaly_PercentSalaryHike  \
# 0                            1.349000                      False
# 1                            0.899333                      False
# 2                            0.000000                      False
# 3                           -1.349000                      False
# 4                            1.349000                      False
#
#    modified_z_score_YearsInCurrentRole  anomaly_YearsInCurrentRole  \
# 0                            -0.674500                       False
# 1                             0.674500                       False
# 2                             0.337250                       False
# 3                             0.449667                       False
# 4                             0.112417                       False
#
#    modified_z_score_YearsSinceLastPromotion  anomaly_YearsSinceLastPromotion  \
# 0                                 -0.449667                            False
# 1                                  1.798667                            False
# 2                                  0.899333                            False
# 3                                  0.674500                            False
# 4                                  0.224833                            False
#
#    modified_z_score_YearsWithCurrManager  anomaly_YearsWithCurrManager
# 0                              -0.674500                         False
# 1                               0.899333                         False
# 2                              -0.674500                         False
# 3                               0.449667                         False
# 4                               1.349000                         False

# %%
# Clean up Cols

z_score_col_names = [col for col in df_no_anomalies.columns if col.startswith("modified_z_score_")]
anomaly_column_names = [col for col in df_no_anomalies.columns if col.startswith("anomaly")]
cos_to_drop = z_score_col_names + anomaly_column_names


df_no_anomalies_cleaned = df_no_anomalies.drop(
    columns=cos_to_drop, 
    # errors="ignore"
)
print(f"Dropped all columns:\n", z_score_col_names)
print(f"Dropped all columns:\n", anomaly_column_names)
# Out:
# Dropped all columns:
#  ['modified_z_score_Age', 'modified_z_score_YearsAtCompany', 'modified_z_score_MonthlyIncome', 'modified_z_score_DistanceFromHome', 'modified_z_score_PercentSalaryHike', 'modified_z_score_YearsInCurrentRole', 'modified_z_score_YearsSinceLastPromotion', 'modified_z_score_YearsWithCurrManager']
# Dropped all columns:
#  ['anomaly_Age', 'anomaly_YearsAtCompany', 'anomaly_MonthlyIncome', 'anomaly_DistanceFromHome', 'anomaly_PercentSalaryHike', 'anomaly_YearsInCurrentRole', 'anomaly_YearsSinceLastPromotion', 'anomaly_YearsWithCurrManager']

# %%
df_no_anomalies_cleaned.tail()
# Out:
#        Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 4994  20.0            35.0        19280.0              34.0      5.0
# 4995  33.0             6.0         8345.0              23.0      1.0
# 4996  22.0            22.0        15322.0              49.0      2.0
# 4998  27.0            31.0        18398.0              19.0      5.0
# 4999  36.0            20.0        13320.0              37.0      4.0
#
#       PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 4994               19.0               2.0                 1.0
# 4995               14.0               3.0                 1.0
# 4996               24.0               2.0                 5.0
# 4998               15.0               4.0                29.0
# 4999                6.0               2.0                17.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 4994                      1.0                   1.0             3.0    Male
# 4995                      0.0                   1.0             2.0  Female
# 4996                      1.0                   3.0             4.0    Male
# 4998                      4.0                  12.0             2.0  Female
# 4999                     16.0                   0.0             3.0  Female
#
#        Department    Education MaritalStatus     JobRole OverTime  \
# 4994           HR          PhD      Divorced     Manager       No
# 4995           HR      Masters       Married   Executive      Yes
# 4996      Finance    Bachelors        Single  Technician       No
# 4998      Finance  High School       Married  Technician      Yes
# 4999  Development  High School       Married  Technician       No
#
#          BusinessTravel Attrition
# 4994  Travel_Frequently        No
# 4995  Travel_Frequently        No
# 4996  Travel_Frequently       Yes
# 4998         Non-Travel       Yes
# 4999         Non-Travel        No

# %%
mean_num_since_promotion = df_no_anomalies_cleaned["YearsAtCompany"].mean()
mean_num_since_promotion
# Out:
# np.float64(18.67490187023782)

# %%
df_no_anomalies_cleaned["YearsAtCompany"].describe()
# Out:
# count    4331.000000
# mean       18.674902
# std        10.966233
# min         1.000000
# 25%         9.000000
# 50%        18.000000
# 75%        28.000000
# max        39.000000
# Name: YearsAtCompany, dtype: float64

# %%
mean_num_since_promotion = df_no_anomalies_cleaned["YearsWithCurrManager"].mean()
mean_num_since_promotion
# Out:
# np.float64(3.6970676518125143)

# %%
mean_num_since_promotion = df_no_anomalies_cleaned["YearsInCurrentRole"].mean()
mean_num_since_promotion
# Out:
# np.float64(8.145693835142)

# %%
mean_num_since_promotion = df_no_anomalies_cleaned["YearsSinceLastPromotion"].mean()
mean_num_since_promotion
# Out:
# np.float64(3.652966982221196)

# %% [markdown]
# ## Note:
#
# After Cleaning data - Looks about right.

# %%
def validate_columns_against_reference(df, reference_column, columns_to_validate):
    """
    Adds a boolean feature `sanity_feature_value_check` that indicates if all values in
    the specified columns are less than or equal to the reference column.
    
    :param df: The DataFrame.
    :param reference_column: The column to use as the reference for the check.
    :param columns_to_validate: A list of columns to compare against the reference column.
    :return: The DataFrame with the new sanity check feature.
    """
    # Initialize sanity_feature_value_check to True
    df['sanity_feature_value_check'] = True
    
    # Loop through the columns to check if any value is greater than the reference column
    for col in columns_to_validate:
        # Check if each value in the column is less than or equal to the reference column, then update the sanity check column
        df['sanity_feature_value_check'] = df['sanity_feature_value_check'] & (df[col] <= df[reference_column])
    
    return df

# %%
df_no_anomalies_cleaned = validate_columns_against_reference(df_no_anomalies_cleaned, 'YearsAtCompany', ["YearsInCurrentRole", "YearsWithCurrManager", "YearsSinceLastPromotion"])
df_no_anomalies_cleaned["sanity_feature_value_check"].value_counts()
# Out:
# sanity_feature_value_check
# True     4327
# False       4
# Name: count, dtype: int64

# %%
df_no_anomalies_cleaned[df_no_anomalies_cleaned["sanity_feature_value_check"] == False][["YearsAtCompany", "YearsInCurrentRole", "YearsWithCurrManager", "YearsSinceLastPromotion"]]
# Out:
#       YearsAtCompany  YearsInCurrentRole  YearsWithCurrManager  \
# 49               6.0                 6.0                   5.0
# 1479             2.0                 1.0                   4.0
# 3189             1.0                 1.0                   1.0
# 4161            14.0                17.0                  15.0
#
#       YearsSinceLastPromotion
# 49                        8.0
# 1479                      1.0
# 3189                      3.0
# 4161                     14.0

# %%
df_no_anomalies_cleaned_sanity = df_no_anomalies_cleaned[df_no_anomalies_cleaned["sanity_feature_value_check"] == True]
df_no_anomalies_cleaned_sanity = df_no_anomalies_cleaned_sanity.drop(columns=["sanity_feature_value_check"])

print(df_no_anomalies_cleaned_sanity.shape)
df_no_anomalies_cleaned_sanity.tail(2)
# Out:
# (4327, 19)
#        Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 4998  27.0            31.0        18398.0              19.0      5.0
# 4999  36.0            20.0        13320.0              37.0      4.0
#
#       PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 4998               15.0               4.0                29.0
# 4999                6.0               2.0                17.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 4998                      4.0                  12.0             2.0  Female
# 4999                     16.0                   0.0             3.0  Female
#
#        Department    Education MaritalStatus     JobRole OverTime  \
# 4998      Finance  High School       Married  Technician      Yes
# 4999  Development  High School       Married  Technician       No
#
#      BusinessTravel Attrition
# 4998     Non-Travel       Yes
# 4999     Non-Travel        No

# %% [markdown]
# ## Notes:
# - Issue here: we see there are 6 fields where the `YearsAtCompany` happens to be smaller than one of ["YearsInCurrentRole", "YearsSinceLastPromotion", "YearsWithCurrManager"]
#
#
# 1x very good example is:
# - A person who has been at the company for 6 years, and has been 6 years in their current role, has had 8 years since their last promotion. That is impossible
# - (OLD) Age of person is 30 but they have worked 35 years at the company (make a joke here - would fit suitably within the latest demanding job craze :D)
#
#
# Conclusion:
# - Dropping these rows since the data is not making sense

# %% [markdown]
# ## Plot Categorical and Numerical Features Against Target

# %%
numeric_columns
# Out:
# Index(['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'PercentSalaryHike', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
from utils.visualisation import plot_numeric_vs_target_boxplot


for feature in numeric_columns:
    plot_numeric_vs_target_boxplot(
        df_no_anomalies_cleaned_sanity,
        numeric_feature=feature, 
        target='Attrition'
    )
# Out:
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})
# /Users/ryanmccarlie/Documents/Problems/PwC Interview/Code/utils/visualisation.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=numeric_feature, data=df, palette={'Yes': 'lightblue', 'No': 'lightcoral'})

# %%
def plot_categorical_vs_target_grouped(df, feature, target):
    """
    Plots a bar chart showing the percentage of a categorical feature's values grouped by the target variable.

    Parameters:
    - df (pd.DataFrame): The input dataframe.
    - feature (str): The categorical feature to plot.
    - target (str): The target variable to group by.

    Returns:
    - fig, axes: Matplotlib figure and axes objects.
    """
    total_counts = df[feature].value_counts()
    
    # Handle both 0/1 and 'Yes'/'No' cases for the target
    attrition_yes_counts = df[df[target] == 1][feature].value_counts()
    attrition_no_counts = df[df[target] == 0][feature].value_counts()

    # Calculate percentages
    attrition_yes_percentage = (attrition_yes_counts / total_counts * 100).fillna(0)
    attrition_no_percentage = (attrition_no_counts / total_counts * 100).fillna(0)
    
    # Create a DataFrame for easier plotting
    percentages_df = pd.DataFrame({
        'Attrition = Yes': attrition_yes_percentage,
        'Attrition = No': attrition_no_percentage
    })

    # Create the figure and axes objects
    fig, axes = plt.subplots(figsize=(10, 6))

    # Plot side-by-side bars
    percentages_df.plot(kind='bar', ax=axes)
    
    # Set plot title and labels
    axes.set_title(f'Percentage of Attrition by {feature}')
    axes.set_ylabel('Attrition Percentage (%)')
    axes.set_xlabel(feature)
    axes.set_xticklabels(axes.get_xticklabels(), rotation=0)
    
    # Return the figure and axes for rendering outside the function
    return fig, axes

# %%
# List of categorical features
# from utils.visualisation import plot_categorical_vs_target_grouped


categorical_features = [
    'MaritalStatus', 'Education', 'Department', 'Gender', 'JobRole', 'OverTime', 
    'BusinessTravel', 'JobLevel', 'JobSatisfaction', 'PerformanceRating'
]

# Assuming df is your DataFrame and 'Attrition' is the target variable
for feature in categorical_features:
    plot_categorical_vs_target_grouped(
        df_no_anomalies_cleaned_sanity,
        feature=feature, 
        target='Attrition'
    )

# %%
df_no_anomalies_cleaned_sanity[["JobRole", "JobLevel"]].value_counts()
# Out:
# JobRole     JobLevel
# Clerk       3.0         203
#             1.0         197
# Manager     5.0         190
# Clerk       2.0         188
#             4.0         185
# Executive   1.0         183
# Technician  4.0         182
# Engineer    3.0         181
# Manager     1.0         178
# Engineer    2.0         177
#             5.0         175
# Technician  3.0         174
# Clerk       5.0         172
# Engineer    1.0         170
# Executive   2.0         168
# Manager     4.0         167
# Technician  2.0         167
#             5.0         165
# Manager     3.0         164
# Technician  1.0         163
# Manager     2.0         160
# Executive   5.0         157
#             4.0         155
#             3.0         155
# Engineer    4.0         151
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Add Dummy Data

# %%
# df_dummy_data = df_no_anomalies_cleaned_sanity.copy()
# df_dummy_data.shape
# Out:
# (4327, 19)

# %%
from utils.feature_engineering import add_random_survey_fields

# %%
# Handle adding 2x dummy data columns
add_dummy_data = True

if add_dummy_data:
    df_dummy_data, fields_added  = add_random_survey_fields(df_no_anomalies_cleaned_sanity, seed_value=random_state_var)

print(f"Add {len(fields_added)} dummy fields: {fields_added}")
df_dummy_data.head(2)
# Out:
# Add 4 dummy fields: ['WorkLifeBalanceScore_dummy', 'WorkPlaceSatisfactionScore_dummy', 'EmployeeEngagementLevel_dummy', 'TrainingOpportunitiesBool_dummy']
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 0  56.0             9.0        19844.0               9.0      4.0
# 1  46.0            29.0         6687.0              39.0      1.0
#
#    PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 0               24.0               2.0                 2.0
# 1               20.0               1.0                14.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 0                      1.0                   0.0             1.0    Male
# 1                     11.0                   7.0             1.0  Female
#
#   Department  Education MaritalStatus     JobRole OverTime     BusinessTravel  \
# 0    Support    Masters       Married  Technician       No  Travel_Frequently
# 1      Sales  Bachelors        Single    Engineer       No         Non-Travel
#
#   Attrition  WorkLifeBalanceScore_dummy  WorkPlaceSatisfactionScore_dummy  \
# 0        No                           4                                 5
# 1        No                           5                                 3
#
#   EmployeeEngagementLevel_dummy  TrainingOpportunitiesBool_dummy
# 0                        Medium                            False
# 1                           Low                            False

# %% [markdown]
# ## 4. Feature Engineering

# %%
df_dummy_data.columns
# Out:
# Index(['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'JobLevel', 'PercentSalaryHike', 'PerformanceRating',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'JobSatisfaction', 'Gender', 'Department', 'Education', 'MaritalStatus',
#        'JobRole', 'OverTime', 'BusinessTravel', 'Attrition',
#        'WorkLifeBalanceScore_dummy', 'WorkPlaceSatisfactionScore_dummy',
#        'EmployeeEngagementLevel_dummy', 'TrainingOpportunitiesBool_dummy'],
#       dtype='object')

# %%
from utils.feature_engineering import apply_feature_engineering

df_w_features, additional_columns = apply_feature_engineering(
    df=df_dummy_data,
    add_dummy_data=True
)
print(f"Add new columns: {additional_columns}")
df_w_features.head()
# Out:
# Error applying performance_rating_job_satisfaction_interaction: unsupported operand type(s) for +: 'Categorical' and 'str'
# Add new columns: ['YearsAtCompanyPerformanceInteraction', 'PercentOfYearsInCurrentRole', 'MaritalGenderInteraction', 'IncomeToDeptAvg', 'AgeGroup', 'DistanceGroup', 'DeptOvertimeRatio', 'OvertimeJobSatisfactionInteraction', 'SatisfactionToJobRoleAvg', 'SalaryHikeToJobLevel', 'YearsSincePromoOverTotalYearsRatio', 'SatisfactionToDepartmentAvg']
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 0  56.0             9.0        19844.0               9.0      4.0
# 1  46.0            29.0         6687.0              39.0      1.0
# 2  32.0            35.0         7357.0               1.0      1.0
# 3  60.0            39.0         2327.0              33.0      1.0
# 4  25.0            14.0        12285.0              38.0      5.0
#
#    PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 0               24.0               2.0                 2.0
# 1               20.0               1.0                14.0
# 2               12.0               1.0                11.0
# 3                0.0               2.0                12.0
# 4               24.0               3.0                 9.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 0                      1.0                   0.0             1.0    Male
# 1                     11.0                   7.0             1.0  Female
# 2                      7.0                   0.0             4.0    Male
# 3                      6.0                   5.0             3.0    Male
# 4                      4.0                   9.0             3.0    Male
#
#   Department    Education MaritalStatus     JobRole OverTime  \
# 0    Support      Masters       Married  Technician       No
# 1      Sales    Bachelors        Single    Engineer       No
# 2         HR          PhD        Single       Clerk       No
# 3    Support          PhD        Single  Technician      Yes
# 4    Support  High School        Single   Executive      Yes
#
#       BusinessTravel Attrition  WorkLifeBalanceScore_dummy  \
# 0  Travel_Frequently        No                           4
# 1         Non-Travel        No                           5
# 2         Non-Travel       Yes                           3
# 3      Travel_Rarely       Yes                           5
# 4      Travel_Rarely       Yes                           5
#
#    WorkPlaceSatisfactionScore_dummy EmployeeEngagementLevel_dummy  \
# 0                                 5                        Medium
# 1                                 3                           Low
# 2                                 3                           Low
# 3                                 4                          High
# 4                                 5                        Medium
#
#    TrainingOpportunitiesBool_dummy  PercentOfYearsInCurrentRole  \
# 0                            False                     0.222222
# 1                            False                     0.482759
# 2                            False                     0.314286
# 3                             True                     0.307692
# 4                            False                     0.642857
#
#    YearsSincePromoOverTotalYearsRatio  SalaryHikeToJobLevel  IncomeToDeptAvg  \
# 0                            0.111111                   6.0         1.803461
# 1                            0.379310                  20.0         0.603178
# 2                            0.200000                  12.0         0.658943
# 3                            0.153846                   0.0         0.211482
# 4                            0.285714                   4.8         1.116485
#
#   SatisfactionToJobRoleAvg SatisfactionToDepartmentAvg  DeptOvertimeRatio  \
# 0                     less                        less           0.486797
# 1                    equal                        less           0.483835
# 2                  greater                       equal           0.474654
# 3                    equal                       equal           0.486797
# 4                  greater                       equal           0.486797
#
#   DistanceGroup  AgeGroup MaritalGenderInteraction  \
# 0         Close       50+             Married_Male
# 1      Very Far     40-50            Single_Female
# 2         Close     30-40              Single_Male
# 3           Far       50+              Single_Male
# 4      Very Far  Under 30              Single_Male
#
#   OvertimeJobSatisfactionInteraction  YearsAtCompanyPerformanceInteraction
# 0                             No_1.0                                  18.0
# 1                             No_1.0                                  29.0
# 2                             No_4.0                                  35.0
# 3                            Yes_3.0                                  78.0
# 4                            Yes_3.0                                  42.0

# %%
df_w_features.columns
# Out:
# Index(['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'JobLevel', 'PercentSalaryHike', 'PerformanceRating',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'JobSatisfaction', 'Gender', 'Department', 'Education', 'MaritalStatus',
#        'JobRole', 'OverTime', 'BusinessTravel', 'Attrition',
#        'WorkLifeBalanceScore_dummy', 'WorkPlaceSatisfactionScore_dummy',
#        'EmployeeEngagementLevel_dummy', 'TrainingOpportunitiesBool_dummy',
#        'PercentOfYearsInCurrentRole', 'YearsSincePromoOverTotalYearsRatio',
#        'SalaryHikeToJobLevel', 'IncomeToDeptAvg', 'SatisfactionToJobRoleAvg',
#        'SatisfactionToDepartmentAvg', 'DeptOvertimeRatio', 'DistanceGroup',
#        'AgeGroup', 'MaritalGenderInteraction',
#        'OvertimeJobSatisfactionInteraction',
#        'YearsAtCompanyPerformanceInteraction'],
#       dtype='object')

# %%
df_w_features.isna().sum()
# Out:
# Age                                     0
# YearsAtCompany                          0
# MonthlyIncome                           0
# DistanceFromHome                        0
# JobLevel                                0
# PercentSalaryHike                       0
# PerformanceRating                       0
# YearsInCurrentRole                      0
# YearsSinceLastPromotion                 0
# YearsWithCurrManager                    0
# JobSatisfaction                         0
# Gender                                  0
# Department                              0
# Education                               0
# MaritalStatus                           0
# JobRole                                 0
# OverTime                                0
# BusinessTravel                          0
# Attrition                               0
# WorkLifeBalanceScore_dummy              0
# WorkPlaceSatisfactionScore_dummy        0
# EmployeeEngagementLevel_dummy           0
# TrainingOpportunitiesBool_dummy         0
# PercentOfYearsInCurrentRole             0
# YearsSincePromoOverTotalYearsRatio      0
# SalaryHikeToJobLevel                    0
# IncomeToDeptAvg                         0
# SatisfactionToJobRoleAvg                0
# SatisfactionToDepartmentAvg             0
# DeptOvertimeRatio                       0
# DistanceGroup                           0
# AgeGroup                                0
# MaritalGenderInteraction                0
# OvertimeJobSatisfactionInteraction      0
# YearsAtCompanyPerformanceInteraction    0
# dtype: int64

# %% [markdown]
# ## 5. Create Numeric target Variable

# %%
target_class_str_mapper = {
    "No": 0,
    "Yes": 1,
}
target_class_str = "Attrition"
target_class = "target"
df_w_features[target_class] = df_w_features[target_class_str].apply(lambda x: target_class_str_mapper[x])
df_w_features = df_w_features.drop(columns=["Attrition"])
df_w_features[target_class].value_counts()
# Out:
# target
# 0    2739
# 1    1588
# Name: count, dtype: int64

# %%
df_w_features.columns[df_w_features.columns.str.endswith("_dummy")]
# Out:
# Index(['WorkLifeBalanceScore_dummy', 'WorkPlaceSatisfactionScore_dummy',
#        'EmployeeEngagementLevel_dummy', 'TrainingOpportunitiesBool_dummy'],
#       dtype='object')

# %%
assert False

# %%
df_w_features.columns
# Out:
# Index(['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'JobLevel', 'PercentSalaryHike', 'PerformanceRating',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'JobSatisfaction', 'Gender', 'Department', 'Education', 'MaritalStatus',
#        'JobRole', 'OverTime', 'BusinessTravel', 'WorkLifeBalanceScore_dummy',
#        'WorkPlaceSatisfactionScore_dummy', 'EmployeeEngagementLevel_dummy',
#        'TrainingOpportunitiesBool_dummy', 'PercentOfYearsInCurrentRole',
#        'YearsSincePromoOverTotalYearsRatio', 'SalaryHikeToJobLevel',
#        'IncomeToDeptAvg', 'SatisfactionToJobRoleAvg',
#        'SatisfactionToDepartmentAvg', 'DeptOvertimeRatio', 'DistanceGroup',
#        'AgeGroup', 'MaritalGenderInteraction',
#        'OvertimeJobSatisfactionInteraction',
#        'YearsAtCompanyPerformanceInteraction', 'target'],
#       dtype='object')

# %%
cols_to_select = list(df_w_features.iloc[:, :18].columns) + [target_class] + ['PercentOfYearsInCurrentRole',
       'YearsSincePromoOverTotalYearsRatio', 'SalaryHikeToJobLevel',
       'IncomeToDeptAvg', 'SatisfactionToJobRoleAvg',
       'SatisfactionToDepartmentAvg', 'DeptOvertimeRatio', 'DistanceGroup',
       'AgeGroup', 'MaritalGenderInteraction',
       'OvertimeJobSatisfactionInteraction',
       'YearsAtCompanyPerformanceInteraction',]
cols_to_select
# Out:
# ['Age',
#  'YearsAtCompany',
#  'MonthlyIncome',
#  'DistanceFromHome',
#  'JobLevel',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'JobSatisfaction',
#  'Gender',
#  'Department',
#  'Education',
#  'MaritalStatus',
#  'JobRole',
#  'OverTime',
#  'BusinessTravel',
#  'target',
#  'PercentOfYearsInCurrentRole',
#  'YearsSincePromoOverTotalYearsRatio',
#  'SalaryHikeToJobLevel',
#  'IncomeToDeptAvg',
#  'SatisfactionToJobRoleAvg',
#  'SatisfactionToDepartmentAvg',
#  'DeptOvertimeRatio',
#  'DistanceGroup',
#  'AgeGroup',
#  'MaritalGenderInteraction',
#  'OvertimeJobSatisfactionInteraction',
#  'YearsAtCompanyPerformanceInteraction']

# %%
from utils.visualisation import plot_correlation_matrix_with_target

# Plot heatmaps showing correlation between each feature and Attrition
plot_correlation_matrix_with_target(
    df=df_w_features[cols_to_select], 
    # df=df_w_features[cols_to_select].drop(columns="Attrition", errors="ignore"), 
    target_column='target',
    figsize=(14,10)
)

# %% [markdown]
# ## ANOVA test for correlation between target and numerical features

# %%
df_anova = df_w_features[cols_to_select]
df_anova.head()
# Out:
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 0  56.0             9.0        19844.0               9.0      4.0
# 1  46.0            29.0         6687.0              39.0      1.0
# 2  32.0            35.0         7357.0               1.0      1.0
# 3  60.0            39.0         2327.0              33.0      1.0
# 4  25.0            14.0        12285.0              38.0      5.0
#
#    PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 0               24.0               2.0                 2.0
# 1               20.0               1.0                14.0
# 2               12.0               1.0                11.0
# 3                0.0               2.0                12.0
# 4               24.0               3.0                 9.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 0                      1.0                   0.0             1.0    Male
# 1                     11.0                   7.0             1.0  Female
# 2                      7.0                   0.0             4.0    Male
# 3                      6.0                   5.0             3.0    Male
# 4                      4.0                   9.0             3.0    Male
#
#   Department    Education MaritalStatus     JobRole OverTime  \
# 0    Support      Masters       Married  Technician       No
# 1      Sales    Bachelors        Single    Engineer       No
# 2         HR          PhD        Single       Clerk       No
# 3    Support          PhD        Single  Technician      Yes
# 4    Support  High School        Single   Executive      Yes
#
#       BusinessTravel  target  PercentOfYearsInCurrentRole  \
# 0  Travel_Frequently       0                     0.222222
# 1         Non-Travel       0                     0.482759
# 2         Non-Travel       1                     0.314286
# 3      Travel_Rarely       1                     0.307692
# 4      Travel_Rarely       1                     0.642857
#
#    YearsSincePromoOverTotalYearsRatio  SalaryHikeToJobLevel  IncomeToDeptAvg  \
# 0                            0.111111                   6.0         1.803461
# 1                            0.379310                  20.0         0.603178
# 2                            0.200000                  12.0         0.658943
# 3                            0.153846                   0.0         0.211482
# 4                            0.285714                   4.8         1.116485
#
#   SatisfactionToJobRoleAvg SatisfactionToDepartmentAvg  DeptOvertimeRatio  \
# 0                     less                        less           0.486797
# 1                    equal                        less           0.483835
# 2                  greater                       equal           0.474654
# 3                    equal                       equal           0.486797
# 4                  greater                       equal           0.486797
#
#   DistanceGroup  AgeGroup MaritalGenderInteraction  \
# 0         Close       50+             Married_Male
# 1      Very Far     40-50            Single_Female
# 2         Close     30-40              Single_Male
# 3           Far       50+              Single_Male
# 4      Very Far  Under 30              Single_Male
#
#   OvertimeJobSatisfactionInteraction  YearsAtCompanyPerformanceInteraction
# 0                             No_1.0                                  18.0
# 1                             No_1.0                                  29.0
# 2                             No_4.0                                  35.0
# 3                            Yes_3.0                                  78.0
# 4                            Yes_3.0                                  42.0

# %%
from utils.stats import run_statistical_tests

run_statistical_tests(df_anova, target="target")
# Out:
# ANOVA Test (Numeric Features):
# P-value for correlation between target and Age: 0.7013
# P-value for correlation between target and YearsAtCompany: 0.1315
# P-value for correlation between target and MonthlyIncome: 0.0001
# P-value for correlation between target and DistanceFromHome: 0.0
# P-value for correlation between target and PercentSalaryHike: 0.4055
# P-value for correlation between target and YearsInCurrentRole: 0.2162
# P-value for correlation between target and YearsSinceLastPromotion: 0.469
# P-value for correlation between target and YearsWithCurrManager: 0.6823
# P-value for correlation between target and PercentOfYearsInCurrentRole: 0.9692
# P-value for correlation between target and YearsSincePromoOverTotalYearsRatio: 0.6469
# P-value for correlation between target and SalaryHikeToJobLevel: 0.0451
# P-value for correlation between target and IncomeToDeptAvg: 0.0001
# P-value for correlation between target and DeptOvertimeRatio: 0.5075
# P-value for correlation between target and YearsAtCompanyPerformanceInteraction: 0.411
#
# Chi-Square Test (Categorical Features):
# P-value for association between target and Gender: 0.0006
# P-value for association between target and Department: 0.6871
# P-value for association between target and Education: 0.7738
# P-value for association between target and MaritalStatus: 0.0
# P-value for association between target and JobRole: 0.4738
# P-value for association between target and OverTime: 0.7668
# P-value for association between target and BusinessTravel: 0.7279
# P-value for association between target and SatisfactionToJobRoleAvg: 0.2264
# P-value for association between target and SatisfactionToDepartmentAvg: 0.2134
# P-value for association between target and MaritalGenderInteraction: 0.0
# P-value for association between target and OvertimeJobSatisfactionInteraction: 0.3254

# %%
save_to_dash = True

if save_to_dash:
    dash_data_post = df_anova.copy()
    dash_data_post = dash_data_post.drop(columns=["Attrition"], errors="ignore")

    dashboard_data_fname = os.path.join(transformed_data_dir, "dashboard_display_data_post_clean.csv")
    dash_data_post.to_csv(dashboard_data_fname, index=False)

# %% [markdown]
# ### Save data out

# %%
# Save raw un scaled and non-one-hot encoded data
cleaned_raw_fname = os.path.join(transformed_data_dir, "cleaned_non_scaled_non_one_hot_data_17_09_2024.csv")
df_w_features.to_csv(cleaned_raw_fname, index=False)

# %%
df_w_features.head(3)
# Out:
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 0  56.0             9.0        19844.0               9.0      4.0
# 1  46.0            29.0         6687.0              39.0      1.0
# 2  32.0            35.0         7357.0               1.0      1.0
#
#    PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 0               24.0               2.0                 2.0
# 1               20.0               1.0                14.0
# 2               12.0               1.0                11.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 0                      1.0                   0.0             1.0    Male
# 1                     11.0                   7.0             1.0  Female
# 2                      7.0                   0.0             4.0    Male
#
#   Department  Education MaritalStatus     JobRole OverTime     BusinessTravel  \
# 0    Support    Masters       Married  Technician       No  Travel_Frequently
# 1      Sales  Bachelors        Single    Engineer       No         Non-Travel
# 2         HR        PhD        Single       Clerk       No         Non-Travel
#
#    WorkLifeBalanceScore_dummy  WorkPlaceSatisfactionScore_dummy  \
# 0                           4                                 5
# 1                           5                                 3
# 2                           3                                 3
#
#   EmployeeEngagementLevel_dummy  TrainingOpportunitiesBool_dummy  \
# 0                        Medium                            False
# 1                           Low                            False
# 2                           Low                            False
#
#    PercentOfYearsInCurrentRole  PromotionToCompanyRatio  SalaryHikeToJobLevel  \
# 0                     0.222222                 0.111111                   6.0
# 1                     0.482759                 0.379310                  20.0
# 2                     0.314286                 0.200000                  12.0
#
#    IncomeToDeptAvg  IncomeToJobRoleAvg  DeptOvertimeRatio DistanceGroup  \
# 0         1.803461            1.759983           0.486797         Close
# 1         0.603178            0.592464           0.483835      Very Far
# 2         0.658943            0.676739           0.474654         Close
#
#   AgeGroup MaritalGenderInteraction OvertimeJobSatisfactionInteraction  \
# 0      50+             Married_Male                             No_1.0
# 1    40-50            Single_Female                             No_1.0
# 2    30-40              Single_Male                             No_4.0
#
#    YearsAtCompanyPerformanceInteraction  target
# 0                                  18.0       0
# 1                                  29.0       0
# 2                                  35.0       1

# %% [markdown]
# ## 6. Encoding Categorical Variables

# %%
categorical_columns = df_w_features.select_dtypes(include=['object', 'category']).columns.tolist()
categorical_columns
# Out:
# ['JobLevel',
#  'PerformanceRating',
#  'JobSatisfaction',
#  'Gender',
#  'Department',
#  'Education',
#  'MaritalStatus',
#  'JobRole',
#  'OverTime',
#  'BusinessTravel',
#  'EmployeeEngagementLevel_dummy',
#  'DistanceGroup',
#  'AgeGroup',
#  'MaritalGenderInteraction',
#  'OvertimeJobSatisfactionInteraction']

# %%
df_transformed = df_w_features.copy()
df_transformed.shape
# Out:
# (4327, 34)

# %%
# def one_hot_encode_selected_columns(df, columns_to_encode):
#     """
#     One-hot encodes the specified object columns and saves the mappings of original columns to the new one-hot encoded columns.
#     Returns the transformed dataframe and a dictionary of mappings.
#     """
#     one_hot_mappings = {}
    
#     # Iterate through the specified columns
#     for column in columns_to_encode:
#         # Perform one-hot encoding on the column
#         dummies = pd.get_dummies(df[column], prefix=column)
#         # Save the mapping of original column to one-hot encoded columns
#         one_hot_mappings[column] = dummies.columns.tolist()
#         # Drop the original column and concatenate the one-hot encoded columns
#         df = df.drop(column, axis=1)
#         df = pd.concat([df, dummies], axis=1)
    
#     return df, one_hot_mappings


def one_hot_encode_selected_columns(df, columns_to_encode):
    """
    One-hot encodes the specified object columns and saves the mappings of original columns to the new one-hot encoded columns.
    If a column contains boolean values (True/False), it is converted to 1/0 instead of one-hot encoding.
    Returns the transformed dataframe and a dictionary of mappings.
    """
    one_hot_mappings = {}
    
    # Iterate through the specified columns
    for column in columns_to_encode:
        # Check if the column is boolean (True/False)
        if df[column].dtype == 'bool':
            # Convert boolean values to 1 and 0
            df[column] = df[column].astype(int)
            one_hot_mappings[column] = [f'{column}_0', f'{column}_1']
        else:
            # Perform one-hot encoding on non-boolean columns
            dummies = pd.get_dummies(df[column], prefix=column)
            # Save the mapping of original column to one-hot encoded columns
            one_hot_mappings[column] = dummies.columns.tolist()
            # Drop the original column and concatenate the one-hot encoded columns
            df = df.drop(column, axis=1)
            df = pd.concat([df, dummies], axis=1)
    
    return df, one_hot_mappings

# %%
if "Attrition" in categorical_columns:
    categorical_columns.remove("Attrition")

categorical_columns
# Out:
# ['JobLevel',
#  'PerformanceRating',
#  'JobSatisfaction',
#  'Gender',
#  'Department',
#  'Education',
#  'MaritalStatus',
#  'JobRole',
#  'OverTime',
#  'BusinessTravel',
#  'EmployeeEngagementLevel_dummy',
#  'DistanceGroup',
#  'AgeGroup',
#  'MaritalGenderInteraction',
#  'OvertimeJobSatisfactionInteraction']

# %%
df_transformed.head(2)
# Out:
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome JobLevel  \
# 0  56.0             9.0        19844.0               9.0      4.0
# 1  46.0            29.0         6687.0              39.0      1.0
#
#    PercentSalaryHike PerformanceRating  YearsInCurrentRole  \
# 0               24.0               2.0                 2.0
# 1               20.0               1.0                14.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobSatisfaction  Gender  \
# 0                      1.0                   0.0             1.0    Male
# 1                     11.0                   7.0             1.0  Female
#
#   Department  Education MaritalStatus     JobRole OverTime     BusinessTravel  \
# 0    Support    Masters       Married  Technician       No  Travel_Frequently
# 1      Sales  Bachelors        Single    Engineer       No         Non-Travel
#
#    WorkLifeBalanceScore_dummy  WorkPlaceSatisfactionScore_dummy  \
# 0                           4                                 5
# 1                           5                                 3
#
#   EmployeeEngagementLevel_dummy  TrainingOpportunitiesBool_dummy  \
# 0                        Medium                            False
# 1                           Low                            False
#
#    PercentOfYearsInCurrentRole  PromotionToCompanyRatio  SalaryHikeToJobLevel  \
# 0                     0.222222                 0.111111                   6.0
# 1                     0.482759                 0.379310                  20.0
#
#    IncomeToDeptAvg  IncomeToJobRoleAvg  DeptOvertimeRatio DistanceGroup  \
# 0         1.803461            1.759983           0.486797         Close
# 1         0.603178            0.592464           0.483835      Very Far
#
#   AgeGroup MaritalGenderInteraction OvertimeJobSatisfactionInteraction  \
# 0      50+             Married_Male                             No_1.0
# 1    40-50            Single_Female                             No_1.0
#
#    YearsAtCompanyPerformanceInteraction  target
# 0                                  18.0       0
# 1                                  29.0       0

# %%
assert "Attrition" not in categorical_columns

df_one_hot, one_hot_mappings = one_hot_encode_selected_columns(df=df_transformed, columns_to_encode=categorical_columns)

print(df_one_hot.shape)
df_one_hot.head()
# Out:
# (4327, 81)
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome  PercentSalaryHike  \
# 0  56.0             9.0        19844.0               9.0               24.0
# 1  46.0            29.0         6687.0              39.0               20.0
# 2  32.0            35.0         7357.0               1.0               12.0
# 3  60.0            39.0         2327.0              33.0                0.0
# 4  25.0            14.0        12285.0              38.0               24.0
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                 2.0                      1.0                   0.0
# 1                14.0                     11.0                   7.0
# 2                11.0                      7.0                   0.0
# 3                12.0                      6.0                   5.0
# 4                 9.0                      4.0                   9.0
#
#    WorkLifeBalanceScore_dummy  WorkPlaceSatisfactionScore_dummy  \
# 0                           4                                 5
# 1                           5                                 3
# 2                           3                                 3
# 3                           5                                 4
# 4                           5                                 5
#
#    TrainingOpportunitiesBool_dummy  PercentOfYearsInCurrentRole  \
# 0                            False                     0.222222
# 1                            False                     0.482759
# 2                            False                     0.314286
# 3                             True                     0.307692
# 4                            False                     0.642857
#
#    PromotionToCompanyRatio  SalaryHikeToJobLevel  IncomeToDeptAvg  \
# 0                 0.111111                   6.0         1.803461
# 1                 0.379310                  20.0         0.603178
# 2                 0.200000                  12.0         0.658943
# 3                 0.153846                   0.0         0.211482
# 4                 0.285714                   4.8         1.116485
#
#    IncomeToJobRoleAvg  DeptOvertimeRatio  \
# 0            1.759983           0.486797
# 1            0.592464           0.483835
# 2            0.676739           0.474654
# 3            0.206384           0.486797
# 4            1.128601           0.486797
#
#    YearsAtCompanyPerformanceInteraction  target  JobLevel_1.0  JobLevel_2.0  \
# 0                                  18.0       0         False         False
# 1                                  29.0       0          True         False
# 2                                  35.0       1          True         False
# 3                                  78.0       1          True         False
# 4                                  42.0       1         False         False
#
#    JobLevel_3.0  JobLevel_4.0  JobLevel_5.0  PerformanceRating_1.0  \
# 0         False          True         False                  False
# 1         False         False         False                   True
# 2         False         False         False                   True
# 3         False         False         False                  False
# 4         False         False          True                  False
#
#    PerformanceRating_2.0  PerformanceRating_3.0  PerformanceRating_4.0  \
# 0                   True                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                   True                  False                  False
# 4                  False                   True                  False
#
#    JobSatisfaction_1.0  JobSatisfaction_2.0  JobSatisfaction_3.0  \
# 0                 True                False                False
# 1                 True                False                False
# 2                False                False                False
# 3                False                False                 True
# 4                False                False                 True
#
#    JobSatisfaction_4.0  Gender_Female  Gender_Male  Department_Development  \
# 0                False          False         True                   False
# 1                False           True        False                   False
# 2                 True          False         True                   False
# 3                False          False         True                   False
# 4                False          False         True                   False
#
#    Department_Finance  Department_HR  Department_Sales  Department_Support  \
# 0               False          False             False                True
# 1               False          False              True               False
# 2               False           True             False               False
# 3               False          False             False                True
# 4               False          False             False                True
#
#    Education_Bachelors  Education_High School  Education_Masters  \
# 0                False                  False               True
# 1                 True                  False              False
# 2                False                  False              False
# 3                False                  False              False
# 4                False                   True              False
#
#    Education_PhD  MaritalStatus_Divorced  MaritalStatus_Married  \
# 0          False                   False                   True
# 1          False                   False                  False
# 2           True                   False                  False
# 3           True                   False                  False
# 4          False                   False                  False
#
#    MaritalStatus_Single  JobRole_Clerk  JobRole_Engineer  JobRole_Executive  \
# 0                 False          False             False              False
# 1                  True          False              True              False
# 2                  True           True             False              False
# 3                  True          False             False              False
# 4                  True          False             False               True
#
#    JobRole_Manager  JobRole_Technician  OverTime_No  OverTime_Yes  \
# 0            False                True         True         False
# 1            False               False         True         False
# 2            False               False         True         False
# 3            False                True        False          True
# 4            False               False        False          True
#
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                      False                              True
# 1                       True                             False
# 2                       True                             False
# 3                      False                             False
# 4                      False                             False
#
#    BusinessTravel_Travel_Rarely  EmployeeEngagementLevel_dummy_High  \
# 0                         False                               False
# 1                         False                               False
# 2                         False                               False
# 3                          True                                True
# 4                          True                               False
#
#    EmployeeEngagementLevel_dummy_Low  EmployeeEngagementLevel_dummy_Medium  \
# 0                              False                                  True
# 1                               True                                 False
# 2                               True                                 False
# 3                              False                                 False
# 4                              False                                  True
#
#    DistanceGroup_Close  DistanceGroup_Moderate  DistanceGroup_Far  \
# 0                 True                   False              False
# 1                False                   False              False
# 2                 True                   False              False
# 3                False                   False               True
# 4                False                   False              False
#
#    DistanceGroup_Very Far  AgeGroup_Under 30  AgeGroup_30-40  AgeGroup_40-50  \
# 0                   False              False           False           False
# 1                    True              False           False            True
# 2                   False              False            True           False
# 3                   False              False           False           False
# 4                    True               True           False           False
#
#    AgeGroup_50+  MaritalGenderInteraction_Divorced_Female  \
# 0          True                                     False
# 1         False                                     False
# 2         False                                     False
# 3          True                                     False
# 4         False                                     False
#
#    MaritalGenderInteraction_Divorced_Male  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    MaritalGenderInteraction_Married_Female  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    MaritalGenderInteraction_Married_Male  \
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    MaritalGenderInteraction_Single_Female  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#    MaritalGenderInteraction_Single_Male  \
# 0                                 False
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                  True
#
#    OvertimeJobSatisfactionInteraction_No_1.0  \
# 0                                       True
# 1                                       True
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_2.0  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_3.0  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_4.0  \
# 0                                      False
# 1                                      False
# 2                                       True
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_Yes_1.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    OvertimeJobSatisfactionInteraction_Yes_2.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    OvertimeJobSatisfactionInteraction_Yes_3.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                        True
# 4                                        True
#
#    OvertimeJobSatisfactionInteraction_Yes_4.0
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False

# %%
one_hot_mappings
# Out:
# {'JobLevel': ['JobLevel_1.0',
#   'JobLevel_2.0',
#   'JobLevel_3.0',
#   'JobLevel_4.0',
#   'JobLevel_5.0'],
#  'PerformanceRating': ['PerformanceRating_1.0',
#   'PerformanceRating_2.0',
#   'PerformanceRating_3.0',
#   'PerformanceRating_4.0'],
#  'JobSatisfaction': ['JobSatisfaction_1.0',
#   'JobSatisfaction_2.0',
#   'JobSatisfaction_3.0',
#   'JobSatisfaction_4.0'],
#  'Gender': ['Gender_Female', 'Gender_Male'],
#  'Department': ['Department_Development',
#   'Department_Finance',
#   'Department_HR',
#   'Department_Sales',
#   'Department_Support'],
#  'Education': ['Education_Bachelors',
#   'Education_High School',
#   'Education_Masters',
#   'Education_PhD'],
#  'MaritalStatus': ['MaritalStatus_Divorced',
#   'MaritalStatus_Married',
#   'MaritalStatus_Single'],
#  'JobRole': ['JobRole_Clerk',
#   'JobRole_Engineer',
#   'JobRole_Executive',
#   'JobRole_Manager',
#   'JobRole_Technician'],
#  'OverTime': ['OverTime_No', 'OverTime_Yes'],
#  'BusinessTravel': ['BusinessTravel_Non-Travel',
#   'BusinessTravel_Travel_Frequently',
#   'BusinessTravel_Travel_Rarely'],
#  'EmployeeEngagementLevel_dummy': ['EmployeeEngagementLevel_dummy_High',
#   'EmployeeEngagementLevel_dummy_Low',
#   'EmployeeEngagementLevel_dummy_Medium'],
#  'DistanceGroup': ['DistanceGroup_Close',
#   'DistanceGroup_Moderate',
#   'DistanceGroup_Far',
#   'DistanceGroup_Very Far'],
#  'AgeGroup': ['AgeGroup_Under 30',
#   'AgeGroup_30-40',
#   'AgeGroup_40-50',
#   'AgeGroup_50+'],
#  'MaritalGenderInteraction': ['MaritalGenderInteraction_Divorced_Female',
#   'MaritalGenderInteraction_Divorced_Male',
#   'MaritalGenderInteraction_Married_Female',
#   'MaritalGenderInteraction_Married_Male',
#   'MaritalGenderInteraction_Single_Female',
#   'MaritalGenderInteraction_Single_Male'],
#  'OvertimeJobSatisfactionInteraction': ['OvertimeJobSatisfactionInteraction_No_1.0',
#   'OvertimeJobSatisfactionInteraction_No_2.0',
#   'OvertimeJobSatisfactionInteraction_No_3.0',
#   'OvertimeJobSatisfactionInteraction_No_4.0',
#   'OvertimeJobSatisfactionInteraction_Yes_1.0',
#   'OvertimeJobSatisfactionInteraction_Yes_2.0',
#   'OvertimeJobSatisfactionInteraction_Yes_3.0',
#   'OvertimeJobSatisfactionInteraction_Yes_4.0']}

# %%
# Save raw un scaled and non-one-hot encoded data
cleaned_raw_non_scaled_fname = os.path.join(transformed_data_dir, "cleaned_non_scaled_17_09_2024.csv")
df_one_hot.to_csv(cleaned_raw_non_scaled_fname, index=False)

# %% [markdown]
# # STOP - HERE DO ALL OF THIS IN TRAINING

# %%
integer_columns = df_one_hot.select_dtypes(include=['int', 'float']).columns.tolist()
integer_columns.remove("target")

for col in bool_dtype_cols:
    integer_columns.remove(col)

integer_columns
# Out:
# ['Age',
#  'YearsAtCompany',
#  'MonthlyIncome',
#  'DistanceFromHome',
#  'PercentSalaryHike',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'WorkLifeBalanceScore_dummy',
#  'WorkPlaceSatisfactionScore_dummy',
#  'PercentOfYearsInCurrentRole',
#  'PromotionToCompanyRatio',
#  'SalaryHikeToJobLevel',
#  'IncomeToDeptAvg',
#  'IncomeToJobRoleAvg',
#  'DeptOvertimeRatio',
#  'YearsAtCompanyPerformanceInteraction']

# %%
from typing import List
from sklearn.preprocessing import StandardScaler
import pandas as pd

def scale_numeric_features(df: pd.DataFrame, numeric_columns: List[str]) -> tuple:
    """
    This function scales the numeric features in the dataframe excluding the target column.
    
    Parameters:
    - df (pd.DataFrame): The input dataframe.
    - target_column (str): The name of the target column to exclude from scaling.

    Returns:
    - df_scaled (pd.DataFrame): The dataframe with scaled numeric features.
    - scaler (StandardScaler): The fitted scaler used for scaling.
    """    
    # Copy the dataframe to avoid altering the original one
    df_scaled = df.copy()
    
    # Initialize and fit the scaler
    scaler = StandardScaler()
    df_scaled[numeric_columns] = scaler.fit_transform(df_scaled[numeric_columns])
    
    return df_scaled, scaler


def reverse_scaling(df_scaled: pd.DataFrame, scaler: StandardScaler, numeric_columns: List[str]) -> pd.DataFrame:
    """
    This function reverses the scaling and returns the dataframe to its original state.
    
    Parameters:
    - df_scaled (pd.DataFrame): The scaled dataframe.
    - scaler (StandardScaler): The fitted scaler used for scaling.
    - original_df (pd.DataFrame): The original dataframe (used for reference to check column types).
    - target_column (str): The name of the target column to exclude from the reverse scaling.
    
    Returns:
    - df_reversed (pd.DataFrame): The dataframe with reversed scaling.
    """
    
    # Copy the scaled dataframe to avoid altering it
    df_reversed = df_scaled.copy()
    
    # Apply inverse transformation to the scaled numeric columns
    df_reversed[numeric_columns] = scaler.inverse_transform(df_scaled[numeric_columns])
    
    return df_reversed

# %%
# Scale numeric features (excluding target column 'Attrition')
df_scaled = df_one_hot.copy()

# Identify numeric columns (excluding the target column)
numeric_columns = df_scaled.select_dtypes(include=[np.number]).columns
numeric_columns = numeric_columns.drop(target_class)
print("numeric_columns: \n", list(numeric_columns))
df_scaled, fitted_scaler = scale_numeric_features(df_scaled, numeric_columns=numeric_columns)

print("Scaled DataFrame:")
df_scaled.head()
# Out:
# numeric_columns:
#  ['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome', 'PercentSalaryHike', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'WorkLifeBalanceScore_dummy', 'RoleToCompanyRatio', 'PromotionToCompanyRatio', 'SalaryHikeToJobLevel', 'IncomeToDeptAvg', 'IncomeToJobRoleAvg', 'DeptOvertimeRatio', 'YearsAtCompanyPerformanceInteraction']
# Scaled DataFrame:
#         Age  YearsAtCompany  MonthlyIncome  DistanceFromHome  \
# 0  1.094496       -0.882370       1.696610         -1.118965
# 1  0.356141        0.940307      -0.851763          1.000423
# 2 -0.677557        1.487110      -0.721991         -1.684135
# 3  1.389839        1.851646      -1.696249          0.576546
# 4 -1.194406       -0.426701       0.232511          0.929777
#
#    PercentSalaryHike  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0           1.645309           -0.866686                -0.667242
# 1           1.096108            0.820303                 1.847459
# 2          -0.002294            0.398556                 0.841578
# 3          -1.649896            0.539138                 0.590108
# 4           1.645309            0.117391                 0.087168
#
#    YearsWithCurrManager Attrition  WorkLifeBalanceScore_dummy  \
# 0             -0.927282        No                    0.696054
# 1              0.825716        No                    1.396495
# 2             -0.927282       Yes                   -0.004388
# 3              0.324860       Yes                    1.396495
# 4              1.326573       Yes                    1.396495
#
#    RoleToCompanyRatio  PromotionToCompanyRatio  SalaryHikeToJobLevel  \
# 0           -0.784017                -0.461042              0.084202
# 1            0.051465                 0.713842              2.704706
# 2           -0.488790                -0.071652              1.207275
# 3           -0.509933                -0.273835             -1.038871
# 4            0.564865                 0.303831             -0.140412
#
#    IncomeToDeptAvg  IncomeToJobRoleAvg  DeptOvertimeRatio  \
# 0         1.727386            1.633195          -0.196852
# 1        -0.851721           -0.872545          -0.427950
# 2        -0.730655           -0.691444          -1.287988
# 3        -1.692701           -1.703805          -0.196852
# 4         0.251538            0.276119          -0.196852
#
#    YearsAtCompanyPerformanceInteraction  target  Gender_Female  Gender_Male  \
# 0                             -0.787480       0          False         True
# 1                             -0.484414       0           True        False
# 2                             -0.319105       1          False         True
# 3                              0.865608       1          False         True
# 4                             -0.126245       1          False         True
#
#    Department_Development  Department_Finance  Department_HR  \
# 0                   False               False          False
# 1                   False               False          False
# 2                   False               False           True
# 3                   False               False          False
# 4                   False               False          False
#
#    Department_Sales  Department_Support  Education_Bachelors  \
# 0             False                True                False
# 1              True               False                 True
# 2             False               False                False
# 3             False                True                False
# 4             False                True                False
#
#    Education_High School  Education_Masters  Education_PhD  \
# 0                  False               True          False
# 1                  False              False          False
# 2                  False              False           True
# 3                  False              False           True
# 4                   True              False          False
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                   False                   True                 False
# 1                   False                  False                  True
# 2                   False                  False                  True
# 3                   False                  False                  True
# 4                   False                  False                  True
#
#    JobRole_Clerk  JobRole_Engineer  JobRole_Executive  JobRole_Manager  \
# 0          False             False              False            False
# 1          False              True              False            False
# 2           True             False              False            False
# 3          False             False              False            False
# 4          False             False               True            False
#
#    JobRole_Technician  OverTime_No  OverTime_Yes  BusinessTravel_Non-Travel  \
# 0                True         True         False                      False
# 1               False         True         False                       True
# 2               False         True         False                       True
# 3                True        False          True                      False
# 4               False        False          True                      False
#
#    BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                              True                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                          True
# 4                             False                          True
#
#    JobLevel_1.0  JobLevel_2.0  JobLevel_3.0  JobLevel_4.0  JobLevel_5.0  \
# 0         False         False         False          True         False
# 1          True         False         False         False         False
# 2          True         False         False         False         False
# 3          True         False         False         False         False
# 4         False         False         False         False          True
#
#    PerformanceRating_1.0  PerformanceRating_2.0  PerformanceRating_3.0  \
# 0                  False                   True                  False
# 1                   True                  False                  False
# 2                   True                  False                  False
# 3                  False                   True                  False
# 4                  False                  False                   True
#
#    PerformanceRating_4.0  JobSatisfaction_1.0  JobSatisfaction_2.0  \
# 0                  False                 True                False
# 1                  False                 True                False
# 2                  False                False                False
# 3                  False                False                False
# 4                  False                False                False
#
#    JobSatisfaction_3.0  JobSatisfaction_4.0  \
# 0                False                False
# 1                False                False
# 2                False                 True
# 3                 True                False
# 4                 True                False
#
#    EmployeeEngagementLevel_dummy_High  EmployeeEngagementLevel_dummy_Low  \
# 0                               False                               True
# 1                               False                               True
# 2                               False                               True
# 3                               False                              False
# 4                                True                              False
#
#    EmployeeEngagementLevel_dummy_Medium  DistanceGroup_Close  \
# 0                                 False                 True
# 1                                 False                False
# 2                                 False                 True
# 3                                  True                False
# 4                                 False                False
#
#    DistanceGroup_Moderate  DistanceGroup_Far  DistanceGroup_Very Far  \
# 0                   False              False                   False
# 1                   False              False                    True
# 2                   False              False                   False
# 3                   False               True                   False
# 4                   False              False                    True
#
#    AgeGroup_Under 30  AgeGroup_30-40  AgeGroup_40-50  AgeGroup_50+  \
# 0              False           False           False          True
# 1              False           False            True         False
# 2              False            True           False         False
# 3              False           False           False          True
# 4               True           False           False         False
#
#    MaritalGenderInteraction_Divorced_Female  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    MaritalGenderInteraction_Divorced_Male  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    MaritalGenderInteraction_Married_Female  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    MaritalGenderInteraction_Married_Male  \
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    MaritalGenderInteraction_Single_Female  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#    MaritalGenderInteraction_Single_Male  \
# 0                                 False
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                  True
#
#    OvertimeJobSatisfactionInteraction_No_1.0  \
# 0                                       True
# 1                                       True
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_2.0  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_3.0  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_4.0  \
# 0                                      False
# 1                                      False
# 2                                       True
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_Yes_1.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    OvertimeJobSatisfactionInteraction_Yes_2.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    OvertimeJobSatisfactionInteraction_Yes_3.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                        True
# 4                                        True
#
#    OvertimeJobSatisfactionInteraction_Yes_4.0
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False

# %%
# Log the scaler model with MLFlow
with mlflow.start_run(
    experiment_id=experiment_id,
    run_name="StandardScaler_Scaling"
):
    mlflow.sklearn.log_model(fitted_scaler, "scaler_model")
    mlflow.log_param("scaled_columns", numeric_columns.tolist())
    mlflow.log_metric("num_columns_scaled", len(numeric_columns))
# Out:
# 2024/09/17 18:41:51 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/09/17 18:41:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
# # Reverse the scaling back to original values
# # Identify numeric columns (excluding the target column)
# df_reversed = reverse_scaling(
#     df_scaled=df_scaled, 
#     scaler=fitted_scaler, 
#     numeric_columns=numeric_columns, 
# )

# print("Reversed DataFrame:")
# df_reversed.head()
# Out:
# Reversed DataFrame:
#     Age  YearsAtCompany  MonthlyIncome  DistanceFromHome  PercentSalaryHike  \
# 0  56.0             9.0        19844.0               9.0               24.0
# 1  46.0            29.0         6687.0              39.0               20.0
# 2  32.0            35.0         7357.0               1.0               12.0
# 3  60.0            39.0         2327.0              33.0                0.0
# 4  25.0            14.0        12285.0              38.0               24.0
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                 2.0                      1.0                   0.0
# 1                14.0                     11.0                   7.0
# 2                11.0                      7.0                   0.0
# 3                12.0                      6.0                   5.0
# 4                 9.0                      4.0                   9.0
#
#    WorkLifeBalanceScore_dummy  RoleToCompanyRatio  ...  \
# 0                         4.0            0.222222  ...
# 1                         5.0            0.482759  ...
# 2                         3.0            0.314286  ...
# 3                         5.0            0.307692  ...
# 4                         5.0            0.642857  ...
#
#    MaritalGenderInteraction_Single_Female  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#    MaritalGenderInteraction_Single_Male  \
# 0                                 False
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                  True
#
#    OvertimeJobSatisfactionInteraction_No_1.0  \
# 0                                       True
# 1                                       True
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_2.0  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_No_3.0  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#   OvertimeJobSatisfactionInteraction_No_4.0  \
# 0                                     False
# 1                                     False
# 2                                      True
# 3                                     False
# 4                                     False
#
#   OvertimeJobSatisfactionInteraction_Yes_1.0  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OvertimeJobSatisfactionInteraction_Yes_2.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    OvertimeJobSatisfactionInteraction_Yes_3.0  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                        True
# 4                                        True
#
#    OvertimeJobSatisfactionInteraction_Yes_4.0
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
# [5 rows x 75 columns]

# %%
df_scaled[integer_columns].describe()
# Out:
#                 Age  YearsAtCompany  MonthlyIncome  DistanceFromHome  \
# count  4.310000e+03    4.310000e+03   4.310000e+03      4.310000e+03
# mean   1.236443e-17   -4.739699e-17  -1.195228e-16      5.852498e-17
# std    1.000116e+00    1.000116e+00   1.000116e+00      1.000116e+00
# min   -2.523446e+00   -1.611441e+00  -1.759585e+00     -1.684135e+00
# 25%   -8.252280e-01   -8.823705e-01  -8.592199e-01     -8.363798e-01
# 50%   -1.303686e-02   -6.216557e-02   1.848395e-02      1.137553e-02
# 75%    8.729898e-01    8.491732e-01   8.584184e-01      8.591309e-01
# max    3.900248e+00    1.851646e+00   1.725663e+00      1.706886e+00
#
#        PercentSalaryHike  YearsInCurrentRole  YearsSinceLastPromotion  \
# count       4.310000e+03        4.310000e+03             4.310000e+03
# mean       -7.913237e-17        9.685472e-17             4.945773e-17
# std         1.000116e+00        1.000116e+00             1.000116e+00
# min        -1.649896e+00       -1.147851e+00            -9.187115e-01
# 25%        -8.260950e-01       -8.666857e-01            -9.187115e-01
# 50%        -2.293647e-03       -3.043560e-01            -4.157715e-01
# 75%         8.215077e-01        5.391385e-01             5.901085e-01
# max         1.645309e+00        3.631952e+00             3.104809e+00
#
#        YearsWithCurrManager  WorkLifeBalanceScore_dummy  RoleToCompanyRatio  \
# count          4.310000e+03                4.310000e+03        4.310000e+03
# mean          -2.143168e-17               -7.418660e-18        2.802605e-17
# std            1.000116e+00                1.000116e+00        1.000116e+00
# min           -9.272823e-01               -1.405271e+00       -1.496633e+00
# 25%           -6.768539e-01               -7.048295e-01       -8.552784e-01
# 50%           -4.264255e-01               -4.387917e-03       -5.911375e-02
# 75%            5.752881e-01                6.960537e-01        7.939198e-01
# max            3.079572e+00                1.396495e+00        1.710141e+00
#
#        PromotionToCompanyRatio  SalaryHikeToJobLevel  IncomeToDeptAvg  \
# count             4.310000e+03          4.310000e+03     4.310000e+03
# mean             -1.483732e-17         -1.384816e-16     4.409981e-17
# std               1.000116e+00          1.000116e+00     1.000116e+00
# min              -9.477797e-01         -1.038871e+00    -1.761991e+00
# 25%              -9.477797e-01         -6.645130e-01    -8.603763e-01
# 50%              -2.906838e-01         -2.901554e-01     2.271188e-02
# 75%               5.124333e-01          2.713811e-01     8.628685e-01
# max               3.432859e+00          3.453421e+00     1.757740e+00
#
#        IncomeToJobRoleAvg  DeptOvertimeRatio  \
# count        4.310000e+03       4.310000e+03
# mean         5.728854e-17       1.371628e-15
# std          1.000116e+00       1.000116e+00
# min         -1.763991e+00      -1.287988e+00
# 25%         -8.607028e-01      -4.279499e-01
# 50%          1.849352e-02      -1.968523e-01
# 75%          8.650423e-01       1.982520e-01
# max          1.808715e+00       1.761029e+00
#
#        YearsAtCompanyPerformanceInteraction
# count                          4.310000e+03
# mean                           2.967464e-17
# std                            1.000116e+00
# min                           -1.255855e+00
# 25%                           -7.874798e-01
# 50%                           -2.915533e-01
# 75%                            5.900936e-01
# max                            3.014623e+00

# %% [markdown]
# ## Save data to transformed dir

# %%
df_scaled.columns
# Out:
# Index(['Age', 'YearsAtCompany', 'MonthlyIncome', 'DistanceFromHome',
#        'PercentSalaryHike', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'WorkLifeBalanceScore_dummy',
#        'RoleToCompanyRatio', 'PromotionToCompanyRatio', 'SalaryHikeToJobLevel',
#        'IncomeToDeptAvg', 'IncomeToJobRoleAvg', 'DeptOvertimeRatio',
#        'YearsAtCompanyPerformanceInteraction', 'target', 'Gender_Female',
#        'Gender_Male', 'Department_Development', 'Department_Finance',
#        'Department_HR', 'Department_Sales', 'Department_Support',
#        'Education_Bachelors', 'Education_High School', 'Education_Masters',
#        'Education_PhD', 'MaritalStatus_Divorced', 'MaritalStatus_Married',
#        'MaritalStatus_Single', 'JobRole_Clerk', 'JobRole_Engineer',
#        'JobRole_Executive', 'JobRole_Manager', 'JobRole_Technician',
#        'OverTime_No', 'OverTime_Yes', 'BusinessTravel_Non-Travel',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'JobLevel_1.0', 'JobLevel_2.0', 'JobLevel_3.0', 'JobLevel_4.0',
#        'JobLevel_5.0', 'PerformanceRating_1.0', 'PerformanceRating_2.0',
#        'PerformanceRating_3.0', 'PerformanceRating_4.0', 'JobSatisfaction_1.0',
#        'JobSatisfaction_2.0', 'JobSatisfaction_3.0', 'JobSatisfaction_4.0',
#        'EmployeeEngagementLevel_dummy_High',
#        'EmployeeEngagementLevel_dummy_Low',
#        'EmployeeEngagementLevel_dummy_Medium', 'DistanceGroup_Close',
#        'DistanceGroup_Moderate', 'DistanceGroup_Far', 'DistanceGroup_Very Far',
#        'AgeGroup_Under 30', 'AgeGroup_30-40', 'AgeGroup_40-50', 'AgeGroup_50+',
#        'MaritalGenderInteraction_Divorced_Female',
#        'MaritalGenderInteraction_Divorced_Male',
#        'MaritalGenderInteraction_Married_Female',
#        'MaritalGenderInteraction_Married_Male',
#        'MaritalGenderInteraction_Single_Female',
#        'MaritalGenderInteraction_Single_Male',
#        'OvertimeJobSatisfactionInteraction_No_1.0',
#        'OvertimeJobSatisfactionInteraction_No_2.0',
#        'OvertimeJobSatisfactionInteraction_No_3.0',
#        'OvertimeJobSatisfactionInteraction_No_4.0',
#        'OvertimeJobSatisfactionInteraction_Yes_1.0',
#        'OvertimeJobSatisfactionInteraction_Yes_2.0',
#        'OvertimeJobSatisfactionInteraction_Yes_3.0',
#        'OvertimeJobSatisfactionInteraction_Yes_4.0'],
#       dtype='object')

# %%
# Save data
cleaned_fname = os.path.join(transformed_data_dir, "cleaned_scaled_data_17_09_2024.csv")
df_scaled.to_csv(cleaned_fname, index=False)
